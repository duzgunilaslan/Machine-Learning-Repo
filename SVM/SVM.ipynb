# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import classification_report, confusion_matrix

# %%
data = pd.read_csv("wine.csv")

# %%
data = pd.DataFrame(data)

# %%
data
# Out:
#      Class   Alcohol  Malic acid       Ash  Alcalinity of ash  Magnesium  \
# 0        1  0.571053    0.205534  0.417112           0.030928   0.326087
# 1        2  0.547368    0.053360  0.181818           0.226804   0.086957
# 2        3  0.636842    0.584980  0.663102           0.639175   0.445652
# 3        1  0.807895    0.280632  0.502674           0.381443   0.380435
# 4        2  0.444737    0.199605  0.491979           0.613402   0.152174
# ..     ...       ...         ...       ...                ...        ...
# 173      1  0.765789    0.195652  0.486631           0.350515   0.413043
# 174      2  0.365789    0.171937  0.443850           0.613402   0.413043
# 175      1  0.736842    0.179842  0.663102           0.340206   0.260870
# 176      1  0.665789    0.191700  0.508021           0.288660   0.510870
# 177      2  0.207895    0.144269  0.336898           0.525773   0.173913
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# ...

# %%
# to separate the data set as a X and y
X = data.drop("Class", axis=1)

# %%
X
# Out:
#       Alcohol  Malic acid       Ash  Alcalinity of ash  Magnesium  \
# 0    0.571053    0.205534  0.417112           0.030928   0.326087
# 1    0.547368    0.053360  0.181818           0.226804   0.086957
# 2    0.636842    0.584980  0.663102           0.639175   0.445652
# 3    0.807895    0.280632  0.502674           0.381443   0.380435
# 4    0.444737    0.199605  0.491979           0.613402   0.152174
# ..        ...         ...       ...                ...        ...
# 173  0.765789    0.195652  0.486631           0.350515   0.413043
# 174  0.365789    0.171937  0.443850           0.613402   0.413043
# 175  0.736842    0.179842  0.663102           0.340206   0.260870
# 176  0.665789    0.191700  0.508021           0.288660   0.510870
# 177  0.207895    0.144269  0.336898           0.525773   0.173913
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0         0.575862    0.510549              0.245283         0.274448
# ...

# %%
y = data.Class

# %%
# split the dataset 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle= True, stratify= y)

# %%
model = SVC()

# %%
#determine the parameter values
param_grid = {"C":(1,10,100,1000),"gamma":(0.1,0.01,0.001,0.0001)}

# %%
# create the Grid Search model
grid_search = GridSearchCV(model, param_grid, cv=10, verbose=10,return_train_score=False)

# %%
grid_search.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 16 candidates, totalling 160 fits
# [CV 1/10; 1/16] START C=1, gamma=0.1............................................
# [CV 1/10; 1/16] END .............C=1, gamma=0.1;, score=1.000 total time=   0.0s
# [CV 2/10; 1/16] START C=1, gamma=0.1............................................
# [CV 2/10; 1/16] END .............C=1, gamma=0.1;, score=1.000 total time=   0.0s
# [CV 3/10; 1/16] START C=1, gamma=0.1............................................
# [CV 3/10; 1/16] END .............C=1, gamma=0.1;, score=0.929 total time=   0.0s
# [CV 4/10; 1/16] START C=1, gamma=0.1............................................
# [CV 4/10; 1/16] END .............C=1, gamma=0.1;, score=0.929 total time=   0.0s
# [CV 5/10; 1/16] START C=1, gamma=0.1............................................
# [CV 5/10; 1/16] END .............C=1, gamma=0.1;, score=1.000 total time=   0.0s
# [CV 6/10; 1/16] START C=1, gamma=0.1............................................
# ...

# %%
# Check the best parameter
grid_search.best_params_
# Out:
# {'C': 10, 'gamma': 0.1}

# %%
# to place the best parameters and fit
model = SVC(C=1, gamma=0.1).fit(X_train, y_train)

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
predict = model.predict(X_test)

# %%
#Control the confusion matrix and classification Report
print("Confusion Matrix: ")
print(confusion_matrix(y_test, predict))
print()
print("Classifiction Report :")
print(classification_report(y_test, predict))
# Out:
# Confusion Matrix:
# [[12  0  0]
#  [ 0 14  0]
#  [ 0  0 10]]
#
# Classifiction Report :
#               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        12
#            2       1.00      1.00      1.00        14
#            3       1.00      1.00      1.00        10
#
#     accuracy                           1.00        36
#    macro avg       1.00      1.00      1.00        36
# weighted avg       1.00      1.00      1.00        36
